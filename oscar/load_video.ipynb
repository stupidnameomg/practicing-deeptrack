# %%
import skvideo.io
import skvideo.datasets
video_path = "./video_1.avi"
videodata = skvideo.io.vread(video_path)[:, :, :, 0]
number_of_frames = videodata.shape[0]
resolution = videodata.shape[1:3]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
type(np.float(videodata[0,0,0]))
# Out:
# /var/folders/f9/1_cg4vy125g7fcmll3dp5j7c0000gn/T/ipykernel_65439/556296410.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   type(np.float(videodata[0,0,0]))
# float

# %%
np.max((np.fft.fft2(videodata[0])))
# Out:
# (62363202+0j)

# %%
test = videodata[800]
testfft = test - np.mean(test)

# %%
plt.imshow(test)
plt.show()
plt.imshow(np.abs(np.fft.fftshift((np.fft.fft2(test)))), cmap='gray')
