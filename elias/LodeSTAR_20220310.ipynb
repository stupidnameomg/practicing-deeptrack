# %%
validation_set_size = 100
BATCH_SIZE = 512
IMAGE_SIZE = 64
NUMBER_OF_PARTICLES = 0.0 #number of extra particles in image will be round(poi(NUMBER_OF_PARTICLES))
Z_RANGE = 20
NEW_MODELS=1
save_model_path = "/content/drive/My Drive/imag_n_real_feb22/"
models_path = "/content/drive/My Drive/imag_n_real_feb21/"

# %%
"""Import everything we need and check gpu"""
# %matplotlib inline

already_installed = !pip list -v | grep deeptrack
if not already_installed:
    # !pip install deeptrack==1.0.1
    # !pip install mat73

import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import deeptrack as dt
import tensorflow.keras as keras
import mat73
from matplotlib import colors
from cycler import cycler
from google.colab import drive

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)    
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

def save_models(models):
    drive.mount('/content/drive')
    for i, model in enumerate(models):
        model.save(save_model_path+f"model{i}")

def load_models(path, NUMBER_OF_MODELS):
    """Load models and return them in a list"""
    drive.mount('/content/drive')
    return [models.load_model(path+f"/model{i}") for i in range(NUMBER_OF_MODELS)]
# Out:
# Collecting deeptrack==1.0.1
#   Downloading deeptrack-1.0.1-py3-none-any.whl (137 kB)
#      |████████████████████████████████| 137 kB 14.8 MB/s
# Collecting pydeepimagej
#   Downloading pydeepimagej-2.3.3.tar.gz (24 kB)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from deeptrack==1.0.1) (2.8.0)
# Requirement already satisfied: tensorflow-probability in /usr/local/lib/python3.7/dist-packages (from deeptrack==1.0.1) (0.16.0)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.16.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 19.4 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deeptrack==1.0.1) (1.21.5)
# Collecting pint
#   Downloading Pint-0.18-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 53.9 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deeptrack==1.0.1) (1.4.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from deeptrack==1.0.1) (0.18.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pint->deeptrack==1.0.1) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from pint->deeptrack==1.0.1) (4.11.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->pint->deeptrack==1.0.1) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->pint->deeptrack==1.0.1) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pint->deeptrack==1.0.1) (3.0.7)
# Collecting scikit-image
#   Downloading scikit_image-0.17.2-cp37-cp37m-manylinux1_x86_64.whl (12.5 MB)
#      |████████████████████████████████| 12.5 MB 53.8 MB/s
# Collecting ruamel.yaml
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 48.5 MB/s
# Collecting datetime
#   Downloading DateTime-4.4-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 655 kB/s
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->deeptrack==1.0.1) (2021.11.2)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->deeptrack==1.0.1) (2.6.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->deeptrack==1.0.1) (7.1.2)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->deeptrack==1.0.1) (3.2.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->deeptrack==1.0.1) (2.4.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->deeptrack==1.0.1) (1.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->deeptrack==1.0.1) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->deeptrack==1.0.1) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->deeptrack==1.0.1) (0.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->matplotlib!=3.0.0,>=2.0.0->scikit-image->deeptrack==1.0.1) (1.15.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from datetime->pydeepimagej->deeptrack==1.0.1) (2018.9)
# Collecting zope.interface
#   Downloading zope.interface-5.4.0-cp37-cp37m-manylinux2010_x86_64.whl (251 kB)
#      |████████████████████████████████| 251 kB 70.5 MB/s
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.6-cp37-cp37m-manylinux1_x86_64.whl (546 kB)
#      |████████████████████████████████| 546 kB 35.6 MB/s
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack==1.0.1) (1.0.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack==1.0.1) (0.5.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack==1.0.1) (3.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack==1.0.1) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack==1.0.1) (57.4.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack==1.0.1) (13.0.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack==1.0.1) (1.13.3)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack==1.0.1) (3.17.3)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 52.0 MB/s
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack==1.0.1) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack==1.0.1) (0.24.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack==1.0.1) (1.6.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack==1.0.1) (2.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack==1.0.1) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack==1.0.1) (1.44.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack==1.0.1) (1.1.2)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack==1.0.1) (2.8.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack==1.0.1) (2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow->deeptrack==1.0.1) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow->deeptrack==1.0.1) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->deeptrack==1.0.1) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->deeptrack==1.0.1) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->deeptrack==1.0.1) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->deeptrack==1.0.1) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->deeptrack==1.0.1) (1.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->deeptrack==1.0.1) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->deeptrack==1.0.1) (3.3.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->deeptrack==1.0.1) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->deeptrack==1.0.1) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->deeptrack==1.0.1) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->deeptrack==1.0.1) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->deeptrack==1.0.1) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->deeptrack==1.0.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->deeptrack==1.0.1) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->deeptrack==1.0.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->deeptrack==1.0.1) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->deeptrack==1.0.1) (3.2.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->deeptrack==1.0.1) (2.7.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability->deeptrack==1.0.1) (0.1.6)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability->deeptrack==1.0.1) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability->deeptrack==1.0.1) (1.3.0)
# Building wheels for collected packages: pydeepimagej
#   Building wheel for pydeepimagej (setup.py) ... done
#   Created wheel for pydeepimagej: filename=pydeepimagej-2.3.3-py3-none-any.whl size=24230 sha256=fe204b7b56bae4e2bd23fbb6ab5f825492d689f85df4121769e13dce89805ce9
#   Stored in directory: /root/.cache/pip/wheels/4a/05/98/e4bba4aca59759f5e635d6de7d953a9c60a3db586dd2d96dee
# Successfully built pydeepimagej
# Installing collected packages: zope.interface, ruamel.yaml.clib, tf-estimator-nightly, scikit-image, ruamel.yaml, datetime, tensorflow-addons, pydeepimagej, pint, deeptrack
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.18.3
#     Uninstalling scikit-image-0.18.3:
#       Successfully uninstalled scikit-image-0.18.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed datetime-4.4 deeptrack-1.0.1 pint-0.18 pydeepimagej-2.3.3 ruamel.yaml-0.17.21 ruamel.yaml.clib-0.2.6 scikit-image-0.17.2 tensorflow-addons-0.16.1 tf-estimator-nightly-2.8.0.dev2021122109 zope.interface-5.4.0
# Collecting mat73
#   Downloading mat73-0.58-py3-none-any.whl (18 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from mat73) (3.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mat73) (1.21.5)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->mat73) (1.5.2)
# Installing collected packages: mat73
# Successfully installed mat73-0.58
# Thu Mar 10 14:39:21 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    27W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
"""Import the validation set"""
""" Function to import used to unpack rows of FFT-field"""
def exp_expand(data,shape):
    x = np.arange(shape[0]) - shape[0] / 2
    y = np.arange(shape[1]) - shape[1] / 2
    X, Y = np.meshgrid(x, y)
    bg=np.zeros((shape[0]*shape[1],))+0j
    X=np.reshape(np.fft.fftshift(X),(shape[0]*shape[1]))
    Y=np.reshape(np.fft.fftshift(Y),(shape[0]*shape[1]))
    RHO=X**2+Y**2
    Inds=np.argsort(RHO)
    Inds=np.sort(Inds[:data.shape[0]])

    bg[Inds[:data.shape[0]]]=data
    bg=np.reshape(bg,(shape[0],shape[1]))
  
    return bg

# Load a matfile with "downsized" ROI:s around particles found in the experimental data 
# Download mat-file from shared drive to your private one if to run in Colab!
drive.mount('/content/drive')
filePath = "/content/drive/My Drive/valset/valset_1.mat"

data = mat73.loadmat(filePath)
data = data['CompletedTraces']

shape = [64, 64]
realM = np.zeros((len(data), 64, 64, 1))
imagM = 1j * np.ones((len(data), 64, 64, 1))
savedParticles = realM + imagM

# This loop unpacks and stores all fields found in the processed video in a 3d-array
for i in range(len(data)):

    roi_data = data[i]['ROI'][0]
    roi_data = np.array(roi_data)[5, :]

    particleROI = np.fft.ifft2(exp_expand(roi_data, shape))
    particleROI = np.fft.fftshift(particleROI)
    particleROI = np.expand_dims(particleROI, axis = -1)

    savedParticles[i, :, :, :] = particleROI
    
training_images = np.stack((np.real(savedParticles[:,:,:,0]), np.imag(savedParticles[:,:,:,0])), axis=-1)[:100,:,:,:]
validation_set = savedParticles[-validation_set_size:,:,:,:]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
"""Create group/equivariance"""

crop_size = 64
padding = 32
wavelength = 525e-9
pixel_size = 114e-9 #??
crop_propagation_forward = dt.get_propagation_matrix((crop_size + 2 * padding, ) * 2, 1e-7, pixel_size * 2, wavelength)
crop_propagation_backward = dt.get_propagation_matrix((crop_size + 2 * padding, ) * 2, -1e-7, pixel_size * 2, wavelength)

args = dt.Arguments(
    translate=lambda: np.random.randn(2)*1,
    rotate=lambda: np.random.uniform(0, np.pi*2),
    z=lambda:np.random.uniform(low=-15, high=15),
)

group = ( 
    dt.Affine(rotate=args.rotate) 
    >> dt.Affine(translate=args.translate) 
    >> dt.Gaussian(sigma=lambda: np.random.rand() * 0.001)
    >> dt.FourierTransform() 
    >> dt.FourierTransformTransformation(crop_propagation_forward, crop_propagation_backward, args.z) 
    >> dt.InverseFourierTransform() 
)

equivariance = (
    dt.models.lodestar.Rotational2DEquivariance(args.rotate)
    >> dt.models.lodestar.TranslationalEquivariance(args.translate)
    >> dt.models.lodestar.Equivariance(-1, args.z, indexes=2)
)

import random
training_set = dt.Value(lambda: random.choice(training_images)) 
#training_set = dt.Value(training_images[0]) 

cropsize = 10
group=group[cropsize:-cropsize,cropsize:-cropsize]

for _ in range(10):
    x = (training_set>>group).update()()
    plt.imshow(x[..., 1])
    plt.show()

# %%
"""Create custom layers"""
from tensorflow.math import abs, angle, real, imag, subtract, multiply
class CustomLayerOne(keras.layers.Layer):
    "Dpes nothing"
    def __init__(self):
        super().__init__()

    def build( self, input_shape):
        super().build(input_shape)

    def call(self, image):
        image = tf.dtypes.complex(image[...,0], image[...,1])
        norm_image = subtract(image, 1)
        return tf.stack([real(norm_image), imag(norm_image), angle(image)], axis=-1)#tf.stack([abs(norm_image), angle(image), real(norm_image), imag(norm_image)], axis=-1)

class CustomLayerTwo(keras.layers.Layer):
    "Takes 2 layers as input and outputs 3 layers."
    def __init__(self):
        super().__init__()

    def build( self, input_shape):
        super().build(input_shape)

    def call(self, image):
        image = tf.dtypes.complex(image[...,0], image[...,1])
        norm_image = subtract(image, 1)
        return tf.stack([real(norm_image), imag(norm_image), abs(norm_image)], axis=-1)#tf.stack([abs(norm_image), angle(image), real(norm_image), imag(norm_image)], axis=-1)

class CustomLayerThree(keras.layers.Layer):
    "Takes 2 layers as input and outputs 4 layers."
    def __init__(self):
        super().__init__()

    def build( self, input_shape):
        super().build(input_shape)

    def call(self, image):
        image = tf.dtypes.complex(image[...,0], image[...,1])
        norm_image = subtract(image, 1)
        return tf.stack([abs(norm_image), angle(image), real(norm_image), imag(norm_image)], axis=-1)

# %%
"""Create models"""
num_outputs = 3

def create_model(custom_layer):
    model = keras.models.Sequential()
    model.add(keras.Input(shape=(IMAGE_SIZE-2*cropsize,IMAGE_SIZE-2*cropsize,2)))
    model.add(custom_layer)
    model.add(keras.layers.Conv2D(32, 3, activation='relu'))
    model.add(keras.layers.Conv2D(32, 3, activation='relu', strides=(2,2)))
    model.add(keras.layers.Conv2D(64, 3, activation='relu'))
    model.add(keras.layers.Conv2D(64, 3, activation='relu'))
    model.add(keras.layers.Conv2D(64, 3, activation='relu'))
    model.add(keras.layers.Conv2D(64, 3, activation='relu'))
    model.add(keras.layers.Conv2D(64, 3, activation='relu'))
    model.add(keras.layers.Conv2D(64, 3, activation='relu'))
    model.add(keras.layers.Conv2D(64, 3, activation='relu'))
    model.add(keras.layers.Conv2D(num_outputs+1,1))
    model = dt.models.LodeSTAR(model=model, input_shape=(None, None, 2), num_outputs=num_outputs)
    model.specs = {"Custom layer": custom_layer}
    model.totalhistory = {"total_loss":[], "consistency_loss":[]}
    model.compile(loss="mae", optimizer=tf.keras.optimizers.Adam())
    return model

models = [create_model(CustomLayerOne()),create_model(CustomLayerTwo()), create_model(CustomLayerThree()), create_model(CustomLayerOne()), create_model(CustomLayerTwo()), create_model(CustomLayerThree())]

# %%
"""Create generator"""
generator = dt.models.lodestar.LodeSTARGenerator(
    training_set,
    num_outputs=num_outputs, 
    transformation_function=(group, equivariance), 
    batch_size=8, 
    min_data_size=200, 
    max_data_size=201,
)

# %%
def save_progress(model, h):
    model.totalhistory["total_loss"].extend(h.history["total_loss"])
    model.totalhistory["consistency_loss"].extend(h.history["consistency_loss"])

def plot_progress(models):
    def moving_average(x, w):
        return np.convolve(x, np.ones(w), 'valid') / w

    cc = (cycler(color=list('bgrcmyk')))
    fig, (ax1, ax2) = plt.subplots(1,2,figsize=(25,6))
    ax1.set_prop_cycle(cc)
    ax2.set_prop_cycle(cc)

    for i, model in enumerate(models):
        ax1.plot(moving_average(model.totalhistory["total_loss"], 10), label=f"{model.specs}")
        ax1.set_xlabel("Epochs")
        ax1.set_ylabel("Total Loss")
        ax1.set_yscale("log")
        ax1.legend()

        ax2.plot(moving_average(model.totalhistory["consistency_loss"], 10), label=f"{model.specs}")
        ax2.set_xlabel("Epochs")
        ax2.set_ylabel("Consistency loss")
        ax2.set_yscale("log")
        ax2.legend()

    ax1.grid(True)
    ax2.grid(True)
    plt.show()

while True:
    with generator:
        for model in models:
            h = model.fit(generator, epochs=10, steps_per_epoch=100)
            save_progress(model, h)
        plot_progress(models)
# Out:
# Generating 201 / 200 samples before starting training
# Epoch 1/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 1.0314 - consistency_loss: 0.0456
# Epoch 2/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 1.2947 - consistency_loss: 0.0657
# Epoch 3/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 0.9529 - consistency_loss: 0.0522
# Epoch 4/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 0.7971 - consistency_loss: 0.0369
# Epoch 5/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 0.8628 - consistency_loss: 0.0400
# Epoch 6/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.9345 - consistency_loss: 0.0493
# Epoch 7/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.8361 - consistency_loss: 0.0400
# Epoch 8/10
# 100/100 [==============================] - 1s 11ms/step - total_loss: 0.8281 - consistency_loss: 0.0452
# Epoch 9/10
# 100/100 [==============================] - 1s 7ms/step - total_loss: 0.8151 - consistency_loss: 0.0399
# Epoch 10/10
# 100/100 [==============================] - 1s 7ms/step - total_loss: 0.7582 - consistency_loss: 0.0341
# Epoch 1/10
# 100/100 [==============================] - 1s 7ms/step - total_loss: 2.6831 - consistency_loss: 0.0949
# Epoch 2/10
# 100/100 [==============================] - 1s 7ms/step - total_loss: 2.5205 - consistency_loss: 0.0774
# Epoch 3/10
# 100/100 [==============================] - 1s 7ms/step - total_loss: 2.5352 - consistency_loss: 0.0814
# Epoch 4/10
# 100/100 [==============================] - 1s 7ms/step - total_loss: 2.5976 - consistency_loss: 0.0854
# Epoch 5/10
# 100/100 [==============================] - 1s 11ms/step - total_loss: 2.6464 - consistency_loss: 0.0877
# Epoch 6/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 2.5657 - consistency_loss: 0.0817
# Epoch 7/10
# 100/100 [==============================] - 2s 15ms/step - total_loss: 2.6214 - consistency_loss: 0.0748
# Epoch 8/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 2.6451 - consistency_loss: 0.0909
# Epoch 9/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 2.5921 - consistency_loss: 0.0834
# Epoch 10/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.5738 - consistency_loss: 0.0752
# Epoch 1/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 1.0282 - consistency_loss: 0.0675
# Epoch 2/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 1.1636 - consistency_loss: 0.0738
# Epoch 3/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 0.9470 - consistency_loss: 0.0619
# Epoch 4/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 0.8804 - consistency_loss: 0.0482
# Epoch 5/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 1.1904 - consistency_loss: 0.0675
# Epoch 6/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.7997 - consistency_loss: 0.0482
# Epoch 7/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.9755 - consistency_loss: 0.0523
# Epoch 8/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.8181 - consistency_loss: 0.0393
# Epoch 9/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 0.9185 - consistency_loss: 0.0472
# Epoch 10/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.8732 - consistency_loss: 0.0471
# Epoch 1/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.5843 - consistency_loss: 0.0715
# Epoch 2/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.5481 - consistency_loss: 0.0590
# Epoch 3/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.5408 - consistency_loss: 0.0530
# Epoch 4/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 2.5732 - consistency_loss: 0.0640
# Epoch 5/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 2.5628 - consistency_loss: 0.0528
# Epoch 6/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 2.4758 - consistency_loss: 0.0486
# Epoch 7/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.4405 - consistency_loss: 0.0424
# Epoch 8/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.5135 - consistency_loss: 0.0556
# Epoch 9/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 2.5317 - consistency_loss: 0.0608
# Epoch 10/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.6359 - consistency_loss: 0.0562
# Epoch 1/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.5684 - consistency_loss: 0.0768
# Epoch 2/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.6763 - consistency_loss: 0.0807
# Epoch 3/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.5782 - consistency_loss: 0.0724
# Epoch 4/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.6214 - consistency_loss: 0.0816
# Epoch 5/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 2.6013 - consistency_loss: 0.0668
# Epoch 6/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 2.5451 - consistency_loss: 0.0767
# Epoch 7/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.5352 - consistency_loss: 0.0600
# Epoch 8/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.5129 - consistency_loss: 0.0587
# Epoch 9/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 2.5431 - consistency_loss: 0.0494
# Epoch 10/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.5629 - consistency_loss: 0.0678
# Epoch 1/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 1.1919 - consistency_loss: 0.0732
# Epoch 2/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 1.0723 - consistency_loss: 0.0800
# Epoch 3/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 1.0160 - consistency_loss: 0.0679
# Epoch 4/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 0.9652 - consistency_loss: 0.0592
# Epoch 5/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 1.1259 - consistency_loss: 0.0740
# Epoch 6/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 1.0147 - consistency_loss: 0.0575
# Epoch 7/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 1.0697 - consistency_loss: 0.0682
# Epoch 8/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 1.0498 - consistency_loss: 0.0654
# Epoch 9/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 0.9530 - consistency_loss: 0.0582
# Epoch 10/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.9477 - consistency_loss: 0.0578
# Generating 201 / 200 samples before starting training
# Epoch 1/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.6818 - consistency_loss: 0.0259
# Epoch 2/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.8156 - consistency_loss: 0.0380
# Epoch 3/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.7081 - consistency_loss: 0.0317
# Epoch 4/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.6813 - consistency_loss: 0.0342
# Epoch 5/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.7354 - consistency_loss: 0.0309
# Epoch 6/10
# 100/100 [==============================] - 1s 15ms/step - total_loss: 0.6757 - consistency_loss: 0.0268
# Epoch 7/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 0.6099 - consistency_loss: 0.0260
# Epoch 8/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 0.5914 - consistency_loss: 0.0272
# Epoch 9/10
# 100/100 [==============================] - 1s 15ms/step - total_loss: 0.5421 - consistency_loss: 0.0346
# Epoch 10/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.6505 - consistency_loss: 0.0314
# Epoch 1/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.4697 - consistency_loss: 0.0645
# Epoch 2/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 2.5014 - consistency_loss: 0.0566
# Epoch 3/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 2.5566 - consistency_loss: 0.0489
# Epoch 4/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 2.5005 - consistency_loss: 0.0558
# Epoch 5/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.4631 - consistency_loss: 0.0602
# Epoch 6/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.5089 - consistency_loss: 0.0641
# Epoch 7/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 2.4812 - consistency_loss: 0.0428
# Epoch 8/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 2.6253 - consistency_loss: 0.0607
# Epoch 9/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.4540 - consistency_loss: 0.0571
# Epoch 10/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.4192 - consistency_loss: 0.0493
# Epoch 1/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 0.7647 - consistency_loss: 0.0347
# Epoch 2/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 0.7413 - consistency_loss: 0.0375
# Epoch 3/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.6712 - consistency_loss: 0.0296
# Epoch 4/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 0.7184 - consistency_loss: 0.0310
# Epoch 5/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 0.6933 - consistency_loss: 0.0324
# Epoch 6/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 0.5919 - consistency_loss: 0.0206
# Epoch 7/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.8110 - consistency_loss: 0.0513
# Epoch 8/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.6094 - consistency_loss: 0.0317
# Epoch 9/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.5934 - consistency_loss: 0.0281
# Epoch 10/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 0.6103 - consistency_loss: 0.0272
# Epoch 1/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.4840 - consistency_loss: 0.0472
# Epoch 2/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 2.6302 - consistency_loss: 0.0539
# Epoch 3/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.4993 - consistency_loss: 0.0381
# Epoch 4/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.4897 - consistency_loss: 0.0440
# Epoch 5/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 2.4622 - consistency_loss: 0.0359
# Epoch 6/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.5627 - consistency_loss: 0.0464
# Epoch 7/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.4771 - consistency_loss: 0.0465
# Epoch 8/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.4775 - consistency_loss: 0.0434
# Epoch 9/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 2.5808 - consistency_loss: 0.0595
# Epoch 10/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.4869 - consistency_loss: 0.0489
# Epoch 1/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.4599 - consistency_loss: 0.0500
# Epoch 2/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 2.5410 - consistency_loss: 0.0544
# Epoch 3/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 2.5893 - consistency_loss: 0.0584
# Epoch 4/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.4555 - consistency_loss: 0.0519
# Epoch 5/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 2.5210 - consistency_loss: 0.0489
# Epoch 6/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.4693 - consistency_loss: 0.0422
# Epoch 7/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 2.5431 - consistency_loss: 0.0481
# Epoch 8/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.5397 - consistency_loss: 0.0587
# Epoch 9/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.4374 - consistency_loss: 0.0444
# Epoch 10/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 2.5042 - consistency_loss: 0.0411
# Epoch 1/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 1.0188 - consistency_loss: 0.0541
# Epoch 2/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 0.9988 - consistency_loss: 0.0586
# Epoch 3/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.8345 - consistency_loss: 0.0447
# Epoch 4/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 0.7881 - consistency_loss: 0.0433
# Epoch 5/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 0.8336 - consistency_loss: 0.0474
# Epoch 6/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 2.8399 - consistency_loss: 0.1790
# Epoch 7/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 1.8850 - consistency_loss: 0.0968
# Epoch 8/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 1.2273 - consistency_loss: 0.0571
# Epoch 9/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 0.9396 - consistency_loss: 0.0489
# Epoch 10/10
# 100/100 [==============================] - 1s 12ms/step - total_loss: 0.8254 - consistency_loss: 0.0420
# Generating 201 / 200 samples before starting training
# Epoch 1/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 0.6679 - consistency_loss: 0.0291
# Epoch 2/10
# 100/100 [==============================] - 1s 13ms/step - total_loss: 0.8950 - consistency_loss: 0.0351
# Epoch 3/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 0.7766 - consistency_loss: 0.0418
# Epoch 4/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 0.7450 - consistency_loss: 0.0378
# Epoch 5/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 0.6576 - consistency_loss: 0.0291
# Epoch 6/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 0.7021 - consistency_loss: 0.0367
# Epoch 7/10
# 100/100 [==============================] - 1s 14ms/step - total_loss: 0.6427 - consistency_loss: 0.0291
# Epoch 8/10
# 100/100 [==============================] - 1s 15ms/step - total_loss: 0.6924 - consistency_loss: 0.0269
# Epoch 9/10
#  73/100 [====================>.........] - ETA: 0s - total_loss: 0.7269 - consistency_loss: 0.0304
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-a9528196adaf> in <module>()
#      32     with generator:
#      33         for model in models:
# ---> 34             h = model.fit(generator, epochs=10, steps_per_epoch=100)
#      35             save_progress(model, h)
#      36         plot_progress(models)
#
# /usr/local/lib/python3.7/dist-packages/deeptrack/models/utils.py in fit(self, x, batch_size, generator_kwargs, *args, **kwargs)
#     229             return None
#     230
# --> 231         return self.model.fit(x, *args, **kwargs)
#     232
#     233     def export(
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1374         callbacks.on_epoch_begin(epoch)
#    1375         with data_handler.catch_stop_iteration():
# -> 1376           for step in data_handler.steps():
#    1377             with tf.profiler.experimental.Trace(
#    1378                 'train',
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in steps(self)
#    1244       if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1245         break
# -> 1246       original_spe = self._steps_per_execution.numpy().item()
#    1247       can_run_full_execution = (
#    1248           original_spe == 1 or
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py in numpy(self)
#     672   def numpy(self):
#     673     if context.executing_eagerly():
# --> 674       return self.read_value().numpy()
#     675     raise NotImplementedError(
#     676         "numpy() is only available when eager execution is enabled.")
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py in read_value(self)
#     750     # Return an identity so it can get placed on whatever device the context
#     751     # specifies instead of the device where the variable is.
# --> 752     return array_ops.identity(value)
#     753
#     754   def sparse_read(self, indices, name=None):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1080       # Fallback dispatch system (dispatch v1):
#    1081       try:
# -> 1082         return dispatch_target(*args, **kwargs)
#    1083       except (TypeError, ValueError):
#    1084         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py in identity(input, name)
#     285     # variables. Variables have correct handle data when graph building.
#     286     input = ops.convert_to_tensor(input)
# --> 287   ret = gen_array_ops.identity(input, name=name)
#     288   # Propagate handle data for happier shape inference for resource variables.
#     289   if hasattr(input, "_handle_data"):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_array_ops.py in identity(input, name)
#    4063     try:
#    4064       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# -> 4065         _ctx, "Identity", name, input)
#    4066       return _result
#    4067     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
#@title
def _propagate_field(field, Tz, z, x, y, K, C, k=2 * np.pi / 0.633):
    """
    Propagate field. Field =  a Complex array of row*col dimension
    """
    Field = np.fft.fft2(field)
    Field = C * Tz * Field
    Field = np.fft.ifft2(Field)

    return Field


def _precalc(field, px, k=2 * np.pi / 0.633):
    """
    Precalculate some constants for propagating field for faster computations.
    """
    yr, xr = field.real.shape

    x = 2 * np.pi / px * np.arange(-(xr / 2 - 1 / 2), (xr / 2 + 1 / 2), 1) / xr
    y = 2 * np.pi / px * np.arange(-(yr / 2 - 1 / 2), (yr / 2 + 1 / 2), 1) / yr
    KXk, KYk = np.meshgrid(x, y)

    K = np.real(
        np.sqrt(np.array(1 - (KXk / k) ** 2 - (KYk / k) ** 2, dtype=np.complex64))
    )
    # Create a circular disk here.
    C = np.fft.fftshift(((KXk / k) ** 2 + (KYk / k) ** 2 < 1) * 1.0)

    return x, y, K, C


def _precalc_Tz(k, zv, K, C):
    return [C * np.fft.fftshift(np.exp(k * 1j * z * (K - 1))) for z in zv]


def propagation_matrix(
    z,
    shape=(IMAGE_SIZE, IMAGE_SIZE),
    padding=64,
    wavelength=525e-9,
    pixel_size=1.13e-6,
):
    field = np.zeros(np.array(shape) + padding * 2)
    k = 2 * np.pi / wavelength * 1e-6
    x, y, K, C = _precalc(field, pixel_size * 1e6, k)
    return _precalc_Tz(k, z, K, C)

def pad_fft2(image, padding):
    im = np.copy(image)
    im = np.pad(im, (padding, padding), mode="symmetric")
    return np.fft.fft2(im)

def ft_transformation(image, Tz, Tzinv, i):
    if i < 0:
        propfac=1
        for j in range(int(np.abs(i))):
            propfac*=Tzinv
        image *= propfac
    else:
        propfac=1
        for j in range(int(np.abs(i))):
            propfac*=Tz
        image *= Tz ** i
    return image

def crop_center(img, cropx, cropy):
    """returns the center of img with size cropx,cropy"""
    y,x = img.shape
    startx = x//2 - cropx//2
    starty = y//2 - cropy//2    
    return img[starty:starty+cropy, startx:startx+cropx]

def propagate(image, z):
    """Re-propagate the images using PAS"""
    image_size = len(image[:,0,0])
    propagate_up, propagate_down = propagation_matrix(
        [.05, -.05],
        shape=(image_size, image_size),
        padding=32,
        wavelength=wavelength,
        pixel_size=pixel_size,
        )
    im = image[:,:,0]
    ft_image = pad_fft2(im, 32)
    prop_ft_image = ft_transformation(ft_image, propagate_down, propagate_up, z)
    return np.expand_dims(crop_center(np.fft.ifft2(prop_ft_image),IMAGE_SIZE, IMAGE_SIZE),axis=-1)

# %%
cc = (cycler(color=list('bgrcmyk')))

def predict_on_stack(model, val_stack):
    """returns a numpy tensor containing propagated distance as well as the prediction, for ever propagation distance and every image images"""
    try:
        dets = np.array(model.predict_and_detect(val_stack, mode="ratio"))
    except:
        dets = np.zeros((val_stack.shape[0],3))
    dets = reshape_dets(dets)
    dets[:,2] *= -0.5
    dets[:,2] -= np.mean(dets[:,2])
    return dets[:,2]

def reshape_dets(dets): #kastar bort alla förutom en detekterad "partikel", alltså inte särskilt smart.
    out = []
    for coord in dets:
        if coord.shape == (1,3):
            out.append(coord)
        else: 
            out.append(coord[-1,:])
    return np.squeeze(np.array(out))

def create_validation_stack(images, z_list):
    """"""
    output = []
    for i in range(images.shape[0]):
        image = images[i,:,:,:]
        stack = []
        for z in z_list:
            stack.append(propagate(image, z))
        output.append(stack)
    return np.stack((np.real(output), np.imag(output)), axis=-1)[:,:,:,:,0,:]

def plot_preds():
    for particle_id in range(from_id, from_id+num_samples):
        dets = model.predict_and_detect(val_stack[particle_id,:,:,:,:], mode="ratio"), 
        plt.figure(figsize=(10, 10))
        plt.imshow(np.abs(val_stack[particle_id,stack_id,:,:,0]+1j*val_stack[particle_id,stack_id,:,:,1]), cmap="bone")
        dets = np.squeeze(np.array(dets))
        plt.scatter(dets[stack_id,1], dets[stack_id,0], s=200, facecolor="none", linewidths=3, edgecolors="g")
        plt.show()
        
        dets[:,2] *= -0.5
        dets[:,2] -= np.mean(dets[:,2])

        [print(d) for d in dets]

def evaluate_model(model, val_stack):
    accs = []
    for i in range(num_samples):
        accs.append(predict_on_stack(model, val_stack[from_id+i]))

    accs = np.array(accs)

    fig, ax = plt.subplots(1,1, figsize=(15,13))
    for i in range(accs.shape[0]):
        ax.plot(prop_range, prop_range, 'k')
        ax.plot(accs[i,:].flatten(), prop_range, '-.')
        ax.grid(True)

    print(f"STD: {np.std((accs-prop_range).flatten()):.3f}", )

# %%
model = models[2]
prop_range = np.linspace(-10, 10, 20)
from_id = 0
num_samples = 7
stack_id = len(prop_range)//2

print(model.specs)
val_stack = create_validation_stack(validation_set, prop_range)

#model.predict_and_detect(val_stack[0,:,cropsize:-cropsize,cropsize:-cropsize,:])
#plot_preds()

evaluate_model(model, val_stack[:,:,:,:,:])
# Out:
# {'Custom layer': <__main__.CustomLayerThree object at 0x7f41cf246c90>}
# (20, 3)
# (20, 3)
# (20, 3)
# (20, 3)
# (20, 3)
# (20, 3)
# (20, 3)
# STD: 1.028
